# %%
#required libraries
# !pip install geopandas
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point, Polygon

#shapefile - keep all the associated files in same folder
france = gpd.read_file('/content/gadm36_FRA_3.shp')

#parameters for geo data
crs = {'init' : 'epsg:4326'}
geometry = [Point(xy) for xy in zip(data["Longitude"], data["Latitude"])]

#defining geo data
geo_data = gpd.GeoDataFrame(data, crs = crs, geometry = geometry)

#actual figure
fig,ax = plt.subplots(figsize = (15,15))
france.plot(ax = ax)
geo_data.plot(kind="scatter", x="Longitude", y="Latitude",
    s=data['PCS delivered']/2, label="Material",                #s is for size of circle
    c="TTC", cmap=plt.get_cmap("jet"),                          #c is for color concentration (should be continuous)
    colorbar=True, alpha=0.5, figsize=(12,12), ax = ax,
)
plt.legend()
plt.show()
