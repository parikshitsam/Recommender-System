# %%
import pandas as pd
import numpy as np
from numpy.random import choice

# %%
data = pd.read_excel("Data.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0  Doc. Date  Material  Order qty  Ship-to nu  PCS delivered  \
# 0           0 2021-01-11     10946        5.0    29606863          350.0
# 1           1 2021-01-11     19898        2.0    29606863          140.0
# 2           2 2021-01-11     80176        4.0    29606863          280.0
# 3           3 2021-01-11     66989        1.0    29606863           70.0
# 4           4 2021-01-08     11766       70.0    29378784           70.0
#
#    HL delivered  delivery_days  delivery_flag  lead_time_creation_vs_rdd_flag  \
# 0          21.0              7              1                               1
# 1           8.4              7              1                               1
# 2          16.8              7              1                               1
# 3           4.2              7              1                               1
# 4           4.2              6              1                               1
#
# ...

# %%
cols = list(data.columns)
pd.Series(cols)
# Out:
# 0                                            Unnamed: 0
# 1                                             Doc. Date
# 2                                              Material
# 3                                             Order qty
# 4                                            Ship-to nu
# 5                                         PCS delivered
# 6                                          HL delivered
# 7                                         delivery_days
# 8                                         delivery_flag
# 9                        lead_time_creation_vs_rdd_flag
# 10                                             MACO/HL
# 11                                           Groupement
# 12                                          Postal Code
# 13                                               Street
# 14                                      Sous groupement
# 15                                      M2_Territory_ID
# 16                                      M1_Territory_ID
# ...

# %%
similar_features_index = [18, 19, 20, 23, 24, 27]
similar_features = [cols[simindex] for simindex in similar_features_index ]
similar_features
# Out:
# ['Brand',
#  'Subrand',
#  'SEGMENTS : Pils / Spécialités / Superspécialités/Bouteille Young adult',
#  'Variétés',
#  'Segment LE',
#  'Degre Alc']

# %%
material_10 = choice(np.array(data.Material.unique()))

# %%
material_10
# Out:
# 78356

# %%
mat_data = data[data['Material'] == material_10]

# %%
mat_data.head(10)
# Out:
#       Unnamed: 0  Doc. Date  Material  Order qty  Ship-to nu  PCS delivered  \
# 245          245 2021-01-19     78356       70.0    29379853           70.0
# 377          377 2021-01-26     78356       70.0    29379283           70.0
# 472          472 2021-01-28     78356       10.0    29379820           10.0
# 492          492 2021-01-28     78356       20.0    29379646           20.0
# 628          628 2021-02-03     78356      140.0    40016990          140.0
# 647          647 2021-02-03     78356       10.0    29379695           10.0
# 718          718 2021-02-08     78356       10.0    29378785           10.0
# 721          721 2021-02-08     78356       40.0    29379820           40.0
# 925          925 2021-02-16     78356       70.0    29379067           70.0
# 1000        1000 2021-02-18     78356       30.0    29379646           30.0
#
#       HL delivered  delivery_days  delivery_flag  \
# 245            4.2              9              1
# ...

# %%
mat_data = mat_data[similar_features]
mat_data
# Out:
#        Brand          Subrand  \
# 245    LEFFE  LEFFE LA LEGERE
# 377    LEFFE  LEFFE LA LEGERE
# 472    LEFFE  LEFFE LA LEGERE
# 492    LEFFE  LEFFE LA LEGERE
# 628    LEFFE  LEFFE LA LEGERE
# ...      ...              ...
# 70743  LEFFE  LEFFE LA LEGERE
# 70744  LEFFE  LEFFE LA LEGERE
# 71566  LEFFE  LEFFE LA LEGERE
# 72008  LEFFE  LEFFE LA LEGERE
# 72045  LEFFE  LEFFE LA LEGERE
#
#       SEGMENTS : Pils / Spécialités / Superspécialités/Bouteille Young adult  \
# 245                                          Spécialités
# 377                                          Spécialités
# 472                                          Spécialités
# 492                                          Spécialités
# 628                                          Spécialités
# ...                                                  ...
# 70743                                        Spécialités
# 70744                                        Spécialités
# ...

# %%
mat_data['Degre Alc'].fillna(method= 'backfill',inplace = True)

# %%
mat_data['Degre Alc'].isna()
# Out:
# 245      False
# 377      False
# 472      False
# 492      False
# 628      False
#          ...
# 70743    False
# 70744    False
# 71566    False
# 72008    False
# 72045    False
# Name: Degre Alc, Length: 202, dtype: bool

# %%
similarities_df = data[similar_features]
similaritoes_df
